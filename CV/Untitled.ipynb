# %%
from PIL import Image
from pylab import *
from numpy import *

# %%
img = Image.open("11.jpg")

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=550x366 at 0x1F35A2DBBA8>

# %%
box=(100,100,400,400)
region=img.crop(box)

# %%
region
# Out:
# <PIL.Image.Image image mode=RGB size=300x300 at 0x1F35A44BC18>

# %%
img.resize((128, 128))
# Out:
# <PIL.Image.Image image mode=RGB size=128x128 at 0x1F35A42E320>

# %%
img.rotate(90)
# Out:
# <PIL.Image.Image image mode=RGB size=550x366 at 0x1F35A44B780>

# %%
imar = array(Image.open("11.jpg").convert("L"))

# %%
imar
# Out:
# array([[172, 172, 172, ..., 201, 201, 202],
#        [172, 172, 173, ..., 201, 201, 202],
#        [173, 173, 174, ..., 201, 201, 202],
#        ...,
#        [ 47,  68,  59, ...,  49,  46,  48],
#        [ 50,  47,  39, ...,  52,  51,  48],
#        [ 34,  18,  32, ...,  59,  57,  56]], dtype=uint8)

# %%
imshow(imar)
title("Plotting NASA building")
# Out:
# Text(0.5,1,'Plotting NASA building')

# %%
figure()
gray()
contour(imar, origin="image")
axis("equal")
axis("off")
# Out:
# (0.5, 549.5, 0.5, 365.5)

# %%
figure()
hist(imar.flatten(), 128)
show()
